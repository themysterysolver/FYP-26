# %% [markdown]
# # FedAvg by dataset size (baseline)
#
# Aggregates client LoRA adapters (MBPP, HumanEval, DS1000) using **size-weighted** Federated Averaging:
# - Weights: \(\alpha_k = n_k / \sum_j n_j\) where \(n_k\) = number of rows in `final_dataset_v2.csv` for dataset \(k\).
# - Output: merged adapter at `aggregated_adapters/fedavg_size/` (compatible with existing Verify notebooks).

# %% [markdown]
# ## 1. Paths and client adapter discovery

# %%
# !pip install -q pandas safetensors torch

# %%
import os
import json
import shutil
import pandas as pd
from pathlib import Path

try:
    NOTEBOOK_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    NOTEBOOK_DIR = os.getcwd()

BASE_DIR = Path(NOTEBOOK_DIR)
CSV_PATH = BASE_DIR / "HUMANEVAL" / "final_dataset_v2.csv"
OUTPUT_DIR = BASE_DIR / "aggregated_adapters" / "fedavg_size_v2"

# Client adapter folders (dataset_name -> path to folder containing adapter_model.safetensors)
CLIENT_CONFIG = {
    "mbpp": BASE_DIR / "MBPP" / "lora_adapters_mbpp",
    "humaneval": BASE_DIR / "HUMANEVAL" / "lora_adapters_x_cross",
    "ds1000": BASE_DIR / "DS1000" / "lora_adapters_ds1000",
}

adapters_found = {k: v for k, v in CLIENT_CONFIG.items() if (v / "adapter_model.safetensors").exists()}
missing = [k for k in CLIENT_CONFIG if k not in adapters_found]
if missing:
    print("Skipping clients (no adapter_model.safetensors):", missing)
print("Clients to aggregate:", list(adapters_found.keys()))
# Out:
# Clients to aggregate: ['mbpp', 'humaneval', 'ds1000']

# %% [markdown]
# ## 2. Compute size-based weights from final_dataset_v2.csv

# %%
df = pd.read_csv(CSV_PATH)
if "dataset" not in df.columns:
    raise ValueError("final_dataset_v2.csv must have a 'dataset' column")

# Normalize dataset names to match CLIENT_CONFIG keys (lowercase)
df["_client"] = df["dataset"].astype(str).str.strip().str.lower()
counts = df["_client"].value_counts()

# Only include clients we have adapters for
n_k = {k: int(counts.get(k, 0)) for k in adapters_found}
total = sum(n_k.values())
if total == 0:
    raise ValueError("No rows in CSV for any of the adapter clients")
alpha = {k: n_k[k] / total for k in adapters_found}

print("Sample counts (n_k):", n_k)
print("Weights (alpha_k):", alpha)
# Out:
# Sample counts (n_k): {'mbpp': 327, 'humaneval': 164, 'ds1000': 1000}
# Weights (alpha_k): {'mbpp': 0.2193158953722334, 'humaneval': 0.10999329309188464, 'ds1000': 0.670690811535882}

# %% [markdown]
# ## 3. Load adapter weights and compute weighted average

# %%
from safetensors import safe_open
import numpy as np

state_dicts = {}
keys_ref = None
for name, path in adapters_found.items():
    p = path / "adapter_model.safetensors"
    with safe_open(str(p), framework="np") as f:
        state_dicts[name] = {k: f.get_tensor(k) for k in f.keys()}

    if keys_ref is None:
        keys_ref = set(state_dicts[name].keys())
    else:
        if set(state_dicts[name].keys()) != keys_ref:
            raise ValueError(f"Adapter keys differ: {name} vs reference")

print("Loaded", len(state_dicts), "adapters; number of keys:", len(keys_ref))

# Weighted average: theta_global = sum_k alpha_k * theta_k
merged = {}
for key in keys_ref:
    merged_tensor = None
    for name, sd in state_dicts.items():
        weighted = sd[key].astype(np.float32, copy=False) * alpha[name]
        merged_tensor = weighted if merged_tensor is None else merged_tensor + weighted
    merged[key] = merged_tensor

print("Merged state dict computed.")
# Out:
# Loaded 3 adapters; number of keys: 504
# Merged state dict computed.

# %% [markdown]
# ## 4. Save merged adapter and config

# %%
# !pip install -q transformers safetensors

# %%
from safetensors.numpy import save_file

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

save_file(merged, str(OUTPUT_DIR / "adapter_model.safetensors"))

# Copy adapter_config.json from first client
first_client_path = adapters_found[list(adapters_found.keys())[0]]
config_src = first_client_path / "adapter_config.json"
if config_src.exists():
    shutil.copy2(str(config_src), str(OUTPUT_DIR / "adapter_config.json"))

# Optionally copy tokenizer/template for convenience
for f in ["tokenizer.json", "tokenizer_config.json", "chat_template.jinja", "README.md"]:
    src = first_client_path / f
    if src.exists():
        shutil.copy2(str(src), str(OUTPUT_DIR / f))

print("Saved to:", OUTPUT_DIR)
# Out:
# Saved to: d:\Desktop\MIT\CODES\FYP-26\FED-CONS-FINAL - TT\aggregated_adapters\fedavg_size_v2

# %% [markdown]
# ## 5. Smoke load (optional)

# %%
# Quick check that the merged adapter loads with PEFT
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

base_id = "Qwen/Qwen2.5-Coder-3B-Instruct"
base_model = AutoModelForCausalLM.from_pretrained(base_id, device_map="auto", trust_remote_code=True)
model = PeftModel.from_pretrained(base_model, str(OUTPUT_DIR))
print("Smoke load OK. Merged adapter is ready for verification notebooks.")
# Out:
# Exception ignored in: <finalize object at 0x1d3052d7800; dead>
# Traceback (most recent call last):
#   File "c:\Users\DELL\anaconda3\Lib\weakref.py", line 588, in __call__
#     info = self._registry.pop(self, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Quick check that the merged adapter loads with PEFT
# ----> 2 from transformers import AutoModelForCausalLM, AutoTokenizer
#       3 from peft import PeftModel
#       5 base_id = "Qwen/Qwen2.5-Coder-3B-Instruct"
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      40     is_pretty_midi_available,
#      41 )
#      43 # Note: the following symbols are deliberately exported with `as`
#      44 # so that mypy, pylint or other static linters can recognize them,
#      45 # given that they are not exported using `__all__` in this file.
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      36     "pyyaml",
#      37 ]
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\utils\__init__.py:22
#      19 from packaging import version
#      21 from .. import __version__
# ---> 22 from .auto_docstring import (
#      23     ClassAttrs,
#      24     ClassDocstring,
#      25     ImageProcessorArgs,
#      26     ModelArgs,
#      27     ModelOutputArgs,
#      28     auto_class_docstring,
#      29     auto_docstring,
#      30     get_args_doc_from_source,
#      31     parse_docstring,
#      32     set_min_indent,
#      33 )
#      34 from .chat_template_utils import DocstringParsingException, TypeHintParsingException, get_json_schema
#      35 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\utils\auto_docstring.py:32
#      24 import regex as re
#      26 from .doc import (
#      27     MODELS_TO_PIPELINE,
#      28     PIPELINE_TASKS_TO_SAMPLE_DOCSTRINGS,
#      29     PT_SAMPLE_DOCSTRINGS,
#      30     _prepare_output_docstrings,
#      31 )
# ---> 32 from .generic import ModelOutput
#      35 PATH_TO_TRANSFORMERS = Path("src").resolve() / "transformers"
#      38 AUTODOC_FILES = [
#      39     "configuration_*.py",
#      40     "modeling_*.py",
#    (...)
#      45     "feature_extractor_*.py",
#      46 ]
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\transformers\utils\generic.py:44
#      41 _is_torch_available = False
#      42 if is_torch_available():
#      43     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 44     import torch
#      45     from torch.types import _dtype
#      47     from ..model_debugging_utils import model_addition_debugger_context
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\__init__.py:2785
#    2781 from torch.func import vmap as vmap
#    2784 if not TYPE_CHECKING:
# -> 2785     from torch import _meta_registrations
#    2787 # Enable CUDA Sanitizer
#    2788 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\_meta_registrations.py:114
#     107     broadcasted_shape = tuple(_broadcast_shapes(self_shape, *args_shape))
#     108     torch._check(
#     109         broadcasted_shape == self_shape,
#     110         lambda: f"output with shape {self_shape} doesn't match the broadcast shape {broadcasted_shape}",
#     111     )
# --> 114 @register_meta([aten.linspace, aten.logspace])
#     115 @out_wrapper()
#     116 def meta_linspace_logspace(
#     117     start,
#     118     end,
#     119     steps,
#     120     base=None,
#     121     dtype=None,
#     122     device=None,
#     123     layout=torch.strided,
#     124     pin_memory=False,
#     125     requires_grad=False,
#     126 ):
#     127     if isinstance(start, torch.Tensor):
#     128         torch._check(
#     129             start.dim() == 0,
#     130             lambda: "linspace only supports 0-dimensional start and end tensors",
#     131         )
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\_meta_registrations.py:71, in register_meta.<locals>.wrapper(fn)
#      68 def register(op):
#      69     _add_op_to_registry(meta_table, op, fn)
# ---> 71 pytree.tree_map_(register, op)
#      72 return fn
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\utils\_pytree.py:1569, in tree_map_(func, tree, is_leaf, *rests)
#    1567 leaves, treespec = tree_flatten(tree, is_leaf=is_leaf)
#    1568 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# -> 1569 deque(map(func, *flat_args), maxlen=0)  # consume and exhaust the iterable
#    1570 return tree
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\_meta_registrations.py:69, in register_meta.<locals>.wrapper.<locals>.register(op)
#      68 def register(op):
# ---> 69     _add_op_to_registry(meta_table, op, fn)
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\torch\_decomp\__init__.py:85, in _add_op_to_registry(registry, op, fn)
#      83 for op_overload in overloads:
#      84     if op_overload in registry:
# ---> 85         raise RuntimeError(f"duplicate registrations for {op_overload}")
#      86     # TorchScript dumps a bunch of extra nonsense overloads
#      87     # which don't have corresponding dispatcher entries, we need
#      88     # to filter those out, e.g aten.add.float_int
#      89     if torch._C._dispatch_has_kernel(op_overload.name()):
#
# RuntimeError: duplicate registrations for aten.linspace.Tensor_Tensor
